# %% [markdown]
# #Q1)Write a Python program to concatenate all elements in a list into a string and return it.

# %%
def list_str(list5):
    final_str=''
    for i in list5:
        final_str = final_str + ' ' + i
    print(final_str)

# %%
list_str(['Mayur','Sudhir','Chavhan'])
# Out:
#  Mayur Sudhir Chavhan
